# %% [markdown]
# # taller de repaso
#
#
#  Multiplica los polinomios
#
# + $ (x + 3) $ y $ (x - 2) $.
#
# + $ (2x^2 + 3x) $ y $ (x + 4) $.
#
# + $ (x^2 - 2x + 1) $ y $ (x + 5) $.
#
# + $ (3x - 4) $ y $ (x^2 + 2x + 1) $.
#
# + $ (2x + 1) $ y $ (4x^2 - x + 3) $.
#
# + $(3x+1)^3$
#
# + $(2x-\frac{1}{3}y^2)^5$
#
#
#
#  Factoriza
#
# + $ 4x^3 - 8x^2 + 12x $.
#
# + $ 15x^4 - 10x^3 + 5x^2 $.
#
# + $ 9x^5y - 12x^4y + 15x^3y $.
#
# + $ 6x^2y^3 + 9x^3y^2 - 3x^4y $.
#
# + $ 7a^3b^2 - 14a^2b + 21ab^3 $.
#
# + $ x^2 + 6x + 9 $.
#
#
# + $ 4x^2 + 12x + 9 $.
#
#
# + $ 25x^2 - 20x + 4 $.
#
# + $ 9x^2 - 24x + 16 $.
#
# + $ 16x^2 + 40x + 25 $.
#
# + $ x^2 - 16 $.
#
# + $ 4x^2 - 25 $.
#
# + $ 9x^2 - 49 $.
#
# + $ 36x^2 - 64 $.
#
# + $ 100x^2 - 81 $.
#
# + $ x^3 - 8 $.
#
# + $ 27x^3 - 1 $.
#
# + $ 64x^3 + 125 $.
#
# + $ 8x^3 + 27 $.
#
# + $ x^3 + 1 $.
