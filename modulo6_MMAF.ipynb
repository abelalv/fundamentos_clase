# %% [markdown]
# # Reto 6: Entendiendo el crecimiento del cancer

# %% [markdown]
# ## Contexto

# %% [markdown]
# Los organismos vivos poseen una gran cantidad de células en sus organismos, las cuales se reproducen de forma regulada para reemplazar a las células envejecidas o dañadas. En ocasiones, las células pueden experimentar daños en su material genético, lo que conlleva consecuencias graves, como el desarrollo de tumores. Es fundamental investigar a fondo los tumores para poder abordarlos de manera efectiva. Un aspecto crucial en esta investigación es analizar la velocidad de crecimiento de los tumores, ya que esto es esencial para el desarrollo de tratamientos eficaces y la mejora de los resultados en los pacientes. Los tumores son formaciones anómalas de tejido que, de no recibir tratamiento, pueden experimentar un crecimiento acelerado. La comprensión de su patrón de crecimiento capacita a los profesionales de la medicina para diseñar intervenciones más exactas.

# %% [markdown]
# ![DALL·E 2024-06-18 12.00.41 - In the Oncology Research Center, a team of scientists is conducting a longitudinal study to better understand tumor growth in cancer patients. The sce.webp](data:image/webp;base64,...)

# %% [markdown]
# # Objetivo

# %% [markdown]
# ### Objetivo general
#
# Desarrollar un modelo matemático que permita predecir la velocidad de crecimiento de un tumor en función del tiempo.

# %% [markdown]
# ### Objetivos específicos
#
# * Comprensión conceptual y gráfica de las funciones exponenciales y logarítmicas: Los estudiantes identificarán y describirán las características clave de las funciones exponenciales y logarítmicas, incluyendo el crecimiento y la decreciente exponencial, sus interceptos, dominio, rango y asíntotas, a través de la representación gráfica y análisis de ecuaciones.
#
# * Resolución de problemas reales utilizando funciones exponenciales y logarítmicas: Los estudiantes aplicarán las propiedades y ecuaciones de funciones exponenciales y logarítmicas para modelar y resolver problemas en contextos biológicos, económicos y de otras ciencias, como el crecimiento poblacional, la descomposición radiactiva o el cálculo de intereses compuestos.
#
# * Conexión entre funciones exponenciales y logarítmicas a través de sus propiedades inversas: Los estudiantes demostrarán la relación inversa entre las funciones exponenciales y logarítmicas, resolviendo ecuaciones que involucren ambas funciones, y utilizando estas propiedades para simplificar expresiones y resolver ecuaciones logarítmicas y exponenciales en diferentes contextos.

# %% [markdown]
# ## Contenido de apoyo

# %% [markdown]
# ### Gráficos de la función exponencial y logarítmica

# %% [markdown]
# La función exponencial es una función matemática, habitual mente se llama la función Euler y se representa de la forma
# $$f(x)=e^x,$$
#  y para calcularla se puede usar la librería `numpy` de Python. por ejemplo, para calcular el valor de la función exponencial en 2, se puede usar el siguiente código:

# %%
import numpy as np
a=np.exp(2)  # calculo de la exponencial de 2
print(a)
# Out:
# 7.38905609893065

# %% [markdown]
# Ahora bien, si queremos graficar la función exponencial, podemos hacerlo de la siguiente manera:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar los puntos para el gráfico
x = np.linspace(-3, 3, 1000)  # Ajustar el rango de valores de x y aumentar la resolución

# Evaluar la función exponencial directamente en los valores de x
y = np.exp(x)

# Graficar la función
plt.plot(x, y)
plt.axhline(0, color='black', linewidth=0.5)  # Agregar una línea en y=0
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de la función $e^x$')
plt.grid(True)
plt.show()

# %% [markdown]
# Recuerde que la función exponencial tiene la forma de una curva que crece rápidamente, y que su dominio es el conjunto de los números reales, de la misma manera, su rango es el conjunto de los números reales positivos.

# %%
import requests
# URL del archivo
url = "https://raw.githubusercontent.com/abelalv/PUJ_MMAF/main/libreria6.py"
# Descargar el archivo
response = requests.get(url)
with open('libreria6.py', 'w') as file:
    file.write(response.text)

import libreria6 as li

from IPython.display import display
import ipywidgets as widgets

# Crear un widget interactivo para la gráfica
exp_widget = widgets.interactive(li.update_grafica_exp, a=li.a_slider, b=li.b_slider, c=li.c_slider,d=li.d_slider)

# Mostrar el widget
display(exp_widget)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='a', max=10.0, min=-10.0), FloatSlider(value=1.0, des…

# %% [markdown]
# # Función logarítmica
#
# La función logarítmica es la función inversa de la función exponencial, en el caso de la función logarítmica natural, se representa de la forma
# $$f(x)=\ln(x),$$
# A para usar la función logaritmo natural en Python, se puede usar la librería `numpy` de Python. Para ellos se puede usar el siguiente código:

# %%
import numpy as np
a=np.log(2)  # Calculo de la funcion logaritmo natural de 2
print(a)
# Out:
# 0.6931471805599453

# %% [markdown]
# ### Gráficos de la función logarítmica
#
# Para generar la gráfica de la función logarítmica hay que tener en cuenta el dominio de la función, puesto que la función $\ln(x)$ esta definida en el intervalo $(0,\infty)$  y se puede usar el siguiente código:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar los puntos para el gráfico
x = np.linspace(0.001, 3, 1000)  # Ajustar el rango de valores de x y aumentar la resolución

# Evaluar la función exponencial directamente en los valores de x
y = np.log(x)

# Graficar la función
plt.plot(x, y)
plt.axhline(0, color='black', linewidth=0.5)  # Agregar una línea en y=0
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de la función $ln(x)$')
plt.grid(True)
plt.show()

# %% [markdown]
# La función logarítmica tiene la forma de una curva que crece lentamente, y su dominio es el conjunto de los números reales positivos, de la misma manera, su rango es el conjunto de los números reales.

# %%
import libreria6 as li
from IPython.display import display
import ipywidgets as widgets

# Crear un widget interactivo para la gráfica
log_widget = widgets.interactive(li.update_grafica_log, a=li.a_slider, b=li.b_slider, c=li.c_slider,d=li.d_slider)

# Mostrar el widget
display(log_widget)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='a', max=10.0, min=-10.0), FloatSlider(value=1.0, des…

# %% [markdown]
# Recuerde que la función logarítmica es la inversa de la función exponencial es decir:
#
# $$y=e^x \Leftrightarrow x=\ln(y),$$
#
# gráficamente se puede observar que
#
# $$ln(e^x)=x,$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar los puntos para el gráfico
x = np.linspace(-3, 3, 1000)  # Ajustar el rango de valores de x y aumentar la resolución

# Evaluar la función exponencial directamente en los valores de x
y = np.log(np.exp(x))

# Graficar la función
plt.plot(x, y)
plt.axhline(0, color='black', linewidth=0.5)  # Agregar una línea en y=0
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de la función $y=ln(e^x)=x$')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Función exponencial y logarítmica de base diferentes

# %% [markdown]
# Ahora si queremos realizar la gráfica de  la función en base 3, es decir
#
# $$f(x)=3^x,$$
#
# se puede  usar las propiedades de las funciones exponenciales para reescribir la función de la siguiente manera:
#
# $$f(x)=3^x= e^{x\ln(3)},$$
#
# de esta forma se usa la función exponencial de Python para graficar la función $f(x)=3^x$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar los puntos para el gráfico
x = np.linspace(-3, 3, 1000)  # Ajustar el rango de valores de x y aumentar la resolución

# Evaluar la función exponencial directamente en los valores de x
y = np.exp(x*np.log(3))

# Graficar la función
plt.plot(x, y)
plt.axhline(0, color='black', linewidth=0.5)  # Agregar una línea en y=0
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de la función $3^x$')
plt.grid(True)
plt.show()

# %% [markdown]
# De esta forma se puede comparar varias funciones exponenciales en el mismo gráfico  y observar como se comportan en el mismo intervalo.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar los puntos para el gráfico
x = np.linspace(-1, 3, 1000)  # Ajustar el rango de valores de x y aumentar la resolución

# Evaluar la función exponencial directamente en los valores de x
y1 = np.exp(x*np.log(3))
y2 = np.exp(x)
y3 = np.exp(x*np.log(2))

# Graficar la función
plt.plot(x, y1,label='$3^x$')
plt.plot(x, y2,label='$e^x$')
plt.plot(x, y3,label='$2^x$')
plt.axhline(0, color='black', linewidth=0.5)  # Agregar una línea en y=0
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Gráfico de la funciones exponenciales')
plt.grid(True)
plt.show()

# %% [markdown]
# De la misma forma podemos realizar la gráfica de la función logarítmica en base 3, es decir
#
# $$f(x)=\log_3(x),$$
#
# usando las propiedades de la función logarítmica y exponencial se puede reescribir la función de la siguiente manera:
#
# $$y=\log_3(x),$$
# $$3^y=3^{\log_3(x)}=x,$$
# $$\ln(3^y)=\ln(x),$$
# $$y\ln(3)=\ln(x),$$
# $$y=\frac{\ln(x)}{\ln(3)},$$

# %% [markdown]
# Usando el cálculo anterior se puede realizar la gráfica de la función logarítmica en base 3, en el intervalo $(0,\infty)$, de la siguiente manera:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar los puntos para el gráfico
x = np.linspace(0.001, 3, 1000)  # Ajustar el rango de valores de x y aumentar la resolución

# Evaluar la función exponencial directamente en los valores de x
y = np.log(x)/np.log(3)

# Graficar la función
plt.plot(x, y)
plt.axhline(0, color='black', linewidth=0.5)  # Agregar una línea en y=0
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de la función $log_3(x)$')
plt.grid(True)
plt.show()

# %% [markdown]
# De esta forma podemos comparar varias funciones logarítmicas en el mismo gráfico y observar como se comportan en el mismo intervalo.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar los puntos para el gráfico
x = np.linspace(0.001, 3, 1000)  # Ajustar el rango de valores de x y aumentar la resolución

# Evaluar la función exponencial directamente en los valores de x
y1 = np.log(x)/np.log(3)
y2 = np.log(x)
y3 = np.log(x)/np.log(2)

# Graficar la función
plt.plot(x, y1,label='$log_3x$')
plt.plot(x, y2,label='$ln x$')
plt.plot(x, y3,label='$log_2x$')
plt.axhline(0, color='black', linewidth=0.5)  # Agregar una línea en y=0
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Gráfico de la funciones exponenciales')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Logaritmo en valor absoluto
#
# La función logaritmo esta definida en el intervalo $(0,\infty)$ y no esta definida en el intervalo $(-\infty,0)$, para poder definir la función logaritmo en el intervalo $(-\infty,\infty)-\{0\}$ se puede usar el valor absoluto de la función logaritmo, es decir
#
# $$f(x)=\ln(|x|),$$
#
# para realizar la gráfica de esta función se puede usar el siguiente código:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar los puntos para el gráfico
x = np.linspace(-3, 3, 1000)  # Ajustar el rango de valores de x y aumentar la resolución

# Evaluar la función exponencial directamente en los valores de x
y = np.log(np.abs(x))

# Graficar la función
plt.plot(x, y)
plt.axhline(0, color='black', linewidth=0.5)  # Agregar una línea en y=0
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de la función $ln|x|$')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Como solucionar ecuaciones  logarítmicas y exponenciales usando la  librería sympy

# %% [markdown]
# De la misma forma que se puede resolver ecuaciones algebraicas, se pueden resolver ecuaciones logarítmicas y exponenciales, para ello se puede usar la librería `sympy` de Python. Por ejemplo, si se quiere resolver la ecuación
#
# $$e^x=3,$$
#
# note que aquí se debe definir la función $e^x$ como una función simbólica de la librería `sympy`

# %%
import sympy  as sp


# Definimos la variable simbólica x como real
x = sp.Symbol('x', real=True)

# Definimos la ecuación

ecuacion = sp.Eq(sp.exp(x) , 3)

# Resolvemos la ecuación
print("Resolviendo la ecuación")
display(ecuacion)
solucion = sp.solve(ecuacion)

print("la solución de la ecuación es:",solucion)
# Out:
# Resolviendo la ecuación
# Eq(exp(x), 3)
# la solución de la ecuación es: [log(3)]

# %% [markdown]
# Ahora en le caso de la ecuación logarítmica

# %% [markdown]
# ## Apropiación y aplicación del contenido
#
#
# 1. Considere la función $f(x)=\dfrac{2 ^{x}}{7}$, grafique la función.
#
# 2. Grafique las funciones y describa que movimientos en el plano respecto a la gráfica de la función  $y=exp(2x)$
#
#  * $y=exp(-2x)$
#
#  * $y=-exp(2x)$
#
#  * $y=-exp(-2x)+6$
#
# 3. Intente gráficar la función $y=exp(10x)$ en el intervalo $[100,1000]$ ¡Que sucede?
#
# 4. La graficar la función $y=0.1^x$ porque decrece para valores de $x$ muy grandes
#
# 5. Grafique la función $y=\log_4(x)$
#
# 6. Resuelva las ecuaciones
#
#  - $ln(x^2-1)=2$
#
#  - $exp(x-1)=100$
#
# 7. Un biólogo está estudiando el crecimiento de una población de bacterias en un laboratorio. La cantidad de bacterias $N(t)$ después de $t$ horas sigue el modelo de crecimiento:
#
# $$
# N(t) = N_0 \cdot e^{kt}
# $$
#
# donde $N_0$ es la cantidad inicial de bacterias y $k$ es la tasa de crecimiento. Después de 5 horas, el biólogo observa que la población de bacterias se ha multiplicado por 16. Si la población inicial era de 100 bacterias, encuentra la tasa de crecimiento $k$.

# %% [markdown]
# ## Familiaridad con el reto

# %% [markdown]
# Una curva logística es la gráfica de una ecuación de la forma
# $$y = \frac{k}{1 + b \cdot e^{-cx}}$$
#
# donde $k$, $b$ y $c$ son constantes positivas. Estas curvas son útiles para describir el crecimiento de un tumor que inicialmente crece rápidamente, pero cuya rapidez de crecimiento disminuye después de que $x$ alcanza cierto valor.
#
# En un estudio famoso del crecimiento de tumores realizado por Gause, se encontró que un tumor estaba descrito por una ecuación logística con $c = 1.1244$, $k = 105$ y $x$ el tiempo en días.
#
# + Encuentre $b$ si la población inicial de células tumorales era de 3.
#
# + En el estudio, la máxima rapidez de crecimiento tuvo lugar en $y = 52$, suponiendo que $b$ es el que se encontró en la población anterior. ¿En qué tiempo $x$ ocurrió esto?
#
# + Justifique porque  después de un largo tiempo, el crecimiento del tumor descrito se aproxima a la constante $k$.

# %% [markdown]
# # Reto
#
# La siguiente ecuación  se usa para describir el crecimiento exponencial de un tumor en sus primeras etapas:
# $$N(t) = N_0 e^{rt},$$
#
# donde $N(t)$ es el número de células tumorales en el tiempo $t$ y $N_0$ es el número inicial de células tumorales. La constante $r$ es la tasa de crecimiento.
#
#
# 1. Cálculo del Número de Células Tumorales
#
#     + Al inicio (tiempo $t = 0$), un tumor tiene 1000 células ($N_0 = 1000$).
#
#     + Suponga una tasa de crecimiento $r = 0.2$ por día.
#
#     + Grafique la función $N(t)$
#
#     + Calcule el número de células tumorales después de 5 días usando la ecuación proporcionada.
#
#
# 2. Tiempo Necesario para Alcanzar un Número Específico de Células
#
#     + Determine cuánto tiempo tomará para que el tumor alcance 10,000 células. (Se sugiere hacer esto a lápiz o papel o usar la gráfica para aproximar una solución)
#
#     + Discuta las limitaciones del modelo exponencial. ¿Qué factores reales podrían afectar el crecimiento de un tumor?
#
# 3.  Vamos a ajustar el concepto de crecimiento logístico, para permitir tener en cuenta la capacidad de carga del entorno. Este ajuste corresponde a la ecuación logística:
#
#     $$    N_l(t) = \frac{N_0 K}{N_0 + (K - N_0)e^{-rt}}, $$
#
#     donde $K$ es la capacidad de carga del entorno (número máximo de células que el entorno puede soportar), $r$ es la tasa de crecimiento intrínseca.
#
#
#     + Compare los modelos exponencial y logístico para un caso donde  $K = 5000$ células y $r = 0.2$ suponiendo que ambos tiene la misma condición inicial, para ello realize la misma gráfica en el plano cartesiano ¿Cuál es más realista?
#
# 4. Si en el tiempo de $t=1$ con una condición inicial de $N_0=10$ y $k=5000$ se tiene que $N(t)=123$, ¿Cuál es el valor de la tasa de crecimiento $r$? ¿para que tiempos los modelos describen el  mismos comportamiento? (Se sugiere usar lápiz y papel para resolver este punto o evaluar la gráfica para aproximar una solución)
